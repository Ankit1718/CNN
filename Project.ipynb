# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-4aa5733b88f9> in <module>
#       1 import numpy as np
#       2 #import panda as pd
# ----> 3 import matplotlib.pyplot as plt
#       4 from skimage import data,filters
#       5
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop


img=image.load_img("C:/Users/ankit123/OneDrive/Desktop/computer vision/basedata/training/valles/PIA04009.tif")
plt.imshow(img)
cv2.imread("C:/Users/ankit123/OneDrive/Desktop/computer vision/basedata/training/valles/PIA04009.tif").shape
train = ImageDataGenerator(rescale= 1/255)
validaton = ImageDataGenerator(rescale= 1/255)
train_dataset = train.flow_from_directory("C:/Users/ankit123/OneDrive/Desktop/computer vision/basedata/training/",
                                        target_size= (1000,1000),batch_size = 3,class_mode ='binary')
validation_dataset = train.flow_from_directory("C:/Users/ankit123/OneDrive/Desktop/computer vision/basedata/validation/",
                                        target_size= (1000,1000),batch_size = 3,class_mode ='binary')
#train_dataset.class_indices
#train_dataset.classes
model =tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape=(1000,1000,3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   #
                                   tf.keras.layers.Conv2D(32,(3,3),activation = 'relu',input_shape=(1000,1000,3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   #
                                   tf.keras.layers.Conv2D(64,(3,3),activation = 'relu',input_shape=(1000,1000,3)),
                                   tf.keras.layers.MaxPool2D(2,2),
                                   ##
                                   tf.keras.layers.Flatten(),
                                   ##
                                   tf.keras.layers.Dense(512,activation= "relu"),
                                   ##
                                   tf.keras.layers.Dense(1,activation= "sigmoid")
                            
                                  ])
model.compile(loss= "binary_crossentropy",optimizer= RMSprop(lr=0.001),metrics =["accuracy"])
model_fit=model.fit(train_dataset,steps_per_epoch=3,epochs=5,validation_data=validation_dataset)
# Out:
# Found 46 images belonging to 2 classes.
# Found 45 images belonging to 2 classes.
# Epoch 1/5
# 3/3 [==============================] - 78s 28s/step - loss: 0.3722 - accuracy: 0.8194 - val_loss: 58.3680 - val_accuracy: 0.7556
# Epoch 2/5
# 3/3 [==============================] - 106s 38s/step - loss: 56.1353 - accuracy: 0.4583 - val_loss: 3.3386 - val_accuracy: 0.7556
# Epoch 3/5
# 3/3 [==============================] - 93s 32s/step - loss: 3.4624 - accuracy: 0.6389 - val_loss: 0.4471 - val_accuracy: 0.8000
# Epoch 4/5
# 3/3 [==============================] - 83s 29s/step - loss: 0.5253 - accuracy: 0.9028 - val_loss: 0.8059 - val_accuracy: 0.7556
# Epoch 5/5
# 3/3 [==============================] - 79s 27s/step - loss: 1.0343 - accuracy: 0.7639 - val_loss: 0.3997 - val_accuracy: 0.8222
# PIA00414.tif
# PIA03847.tif
# PIA04009.tif
# PIA06968.tif
# PIA09437.tif
# PIA09452.tif
# PIA12345.tif
# PIA13007.tif
# PIA13837.tif
# PIA14371.tif
# PIA15168.tif
# PIA15215.tif
# PIA15935.tif
# ...

# %%
dir_path ="C:/Users/ankit123/OneDrive/Desktop/computer vision/basedata/testing"
for i in os.listdir(dir_path):

 img=image.load_img(dir_path+'//'+ i,target_size=(1000,1000))
 plt.imshow(img)
 plt.show()
 X=image.img_to_array(img)
 X=np.expand_dims(X,axis=0)   
 images =np.vstack([X])
 val=model.predict(images)
 if val == 0:
        print("No valles exist")
 else:   
        print("Contains valles")
# Out:
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# No valles exist
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# No valles exist
# No valles exist
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# Contains valles
# No valles exist
# Contains valles
# No valles exist

# %%
validation_dataset.class_indices
# Out:
# {'nonvalles': 0, 'valles': 1}
